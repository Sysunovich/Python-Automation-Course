# %%
message = "Hello World!"
print(type(message))
print(hex(id(message)))
print(message)
# Out:
# <class 'str'>
# 0x1ca5a44d670
# Hello World!

# %%
message = "hello"
message = "world"
print(message)
# Out:
# world

# %%
a = b = 2
print(a)
print(b)
# Out:
# 2
# 2
